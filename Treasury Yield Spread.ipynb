# %% [raw]
# Here is an example of a complete treasury yield data model in a Jupyter Notebook using Python, including data retrieval, analysis, and visualization. In this example, we will retrieve the yields for 2-year, 10-year, and 30-year Treasury bonds and compare their performance over a specific time period.

# %%
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')

start_date = '2020-01-01'
end_date = '2023-03-17'

data = web.DataReader(['DGS2', 'DGS10', 'DGS30'], 'fred', start_date, end_date)

data = data.dropna()

returns = data.pct_change()

cumulative_returns = (1 + returns).cumprod() - 1

plt.figure(figsize=(12, 8))
plt.plot(cumulative_returns)
plt.legend(['2-year', '10-year', '30-year'])
plt.title('Cumulative Returns for Treasury Yields')
plt.xlabel('Date')
plt.ylabel('Cumulative Return')
plt.show()

# %%
correlation_matrix = returns.corr()

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix for Treasury Yields')
plt.show()
